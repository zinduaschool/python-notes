# %%
# Importing libraries to use
import requests
import pandas

# %%
# Get request from the server
url = 'https://rickandmortyapi.com/api'
endpoint = '/character'
requests.get(url+endpoint) # able to concatenate because they are string

# %%
def page_request(url,endpoint,page):
  response=requests.get(url+endpoint+f'?page={page}')
  return response.json()

# %%
def get_pages(response):
  return response['info']['pages'] # all the pages

# %%
# get the information about the characters
def parse_json(response):
  # I want to be able to loop through all the items in the list and get the results
  character_list = []
  for item in response['results']:
    char = {
      'name':  item['name'],
      'species':item['species'],
      'number_of_episodes':len(item['episode'])
    }
    character_list.append(char)
  return character_list

# %%
# To loop through all the pages and give us the characters
character_list_main =[]
for x in range(1,get_pages(data)+1):
  character_list_main.extend(parse_json(page_request(url,endpoint,x)))

# %%
pandas.DataFrame(character_list_main).head() # This part of the code, you don't need to stress about
# Out:
#            name species  number_of_episodes
# 0  Rick Sanchez   Human                  51
# 1   Morty Smith   Human                  51
# 2  Summer Smith   Human                  42
# 3    Beth Smith   Human                  42
# 4   Jerry Smith   Human                  39

# %%
pandas.DataFrame(character_list_main).tail()
# Out:
#              name species  number_of_episodes
# 821   Young Jerry   Human                   1
# 822    Young Beth   Human                   1
# 823    Young Beth   Human                   1
# 824   Young Jerry   Human                   1
# 825  Butter Robot   Robot                   1
